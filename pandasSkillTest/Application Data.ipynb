# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import DisplayObject, display
# %matplotlib inline

# %%
df = pd.read_csv('application_data.csv')

# %%
df.head()
# Out:
#   customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0  839247458  302953235622      2018-12-21           1      7500.0
# 1  217540860  302960101337      2018-12-23           1      7500.0
# 2  522238092  303016988846      2019-01-08           1      7500.0
# 3  096754469  302999605504      2019-01-04           1      7500.0
# 4  410354345  302951945878      2018-12-21           1      7500.0
#
#    InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0          30.0        30       2019-01-20        2019-01-16
# 1          30.0        30       2019-01-22        2018-12-29
# 2          30.0        30       2019-02-07        2019-01-08
# 3          30.0        30       2019-02-03        2019-01-08
# 4          30.0        30       2019-01-20        2019-01-17

# %%
df.dtypes
# Out:
# customerID            object
# loanId                object
# appilcationDate       object
# LoanNumber             int64
# LoanAmount           float64
# InterestRate         float64
# TermDays               int64
# repaymentDueDate      object
# repaymentPaidDate     object
# dtype: object

# %%
df.appilcationDate=pd.to_datetime(df.appilcationDate)
df.repaymentDueDate=pd.to_datetime(df.repaymentDueDate)
df.repaymentPaidDate=pd.to_datetime(df.repaymentPaidDate)

# %%
df.head()
# Out:
#   customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0  839247458  302953235622      2018-12-21           1      7500.0
# 1  217540860  302960101337      2018-12-23           1      7500.0
# 2  522238092  303016988846      2019-01-08           1      7500.0
# 3  096754469  302999605504      2019-01-04           1      7500.0
# 4  410354345  302951945878      2018-12-21           1      7500.0
#
#    InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0          30.0        30       2019-01-20        2019-01-16
# 1          30.0        30       2019-01-22        2018-12-29
# 2          30.0        30       2019-02-07        2019-01-08
# 3          30.0        30       2019-02-03        2019-01-08
# 4          30.0        30       2019-01-20        2019-01-17

# %%
df.dtypes
# Out:
# customerID                   object
# loanId                       object
# appilcationDate      datetime64[ns]
# LoanNumber                    int64
# LoanAmount                  float64
# InterestRate                float64
# TermDays                      int64
# repaymentDueDate     datetime64[ns]
# repaymentPaidDate    datetime64[ns]
# dtype: object

# %%
grouped_data = df.groupby(['LoanAmount', 'InterestRate', 'TermDays'])

# %%
df.describe()
# Out:
#         LoanNumber     LoanAmount  InterestRate    TermDays
# count  1000.000000    1000.000000   1000.000000  1000.00000
# mean      2.691000   13828.080000     23.061700    42.07500
# std       2.789139   19362.887991      8.415945    34.79339
# min       1.000000      80.000000      5.000000    15.00000
# 25%       1.000000    7500.000000     15.000000    30.00000
# 50%       2.000000    7500.000000     30.000000    30.00000
# 75%       3.000000   11000.000000     30.000000    45.00000
# max      26.000000  166000.000000     36.000000   180.00000

# %%
grouped_data.mean()
# Out:
#                                   LoanNumber
# LoanAmount InterestRate TermDays
# 80.0       15.0         15          2.674603
# 1500.0     15.0         15          2.333333
# 2000.0     15.0         15          1.000000
# 3000.0     15.0         15          1.636364
#            30.0         30          1.000000
# 3500.0     15.0         15          5.000000
# 4000.0     15.0         15          4.666667
#            30.0         30          1.000000
# 5000.0     30.0         30          2.000000
#            36.0         45          2.000000
# 7000.0     12.5         30          3.000000
#            15.0         15          2.000000
#                         30         13.000000
#            20.0         30          5.666667
#            20.1         30          1.333333
#            27.0         45          1.000000
#            30.0         30          1.000000
#            36.0         45          1.000000
# 7500.0     20.0         30         12.000000
# ...
